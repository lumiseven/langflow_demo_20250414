# %% [markdown]
# ## 简单的API调用

# %%
import requests
url = "http://127.0.0.1:7860/api/v1/run/bab7bc55-6ffb-48a9-af06-c9a65cd11e60"  # The complete API endpoint URL for this flow

# Request payload configuration
payload = {
    "input_value": "hello world!",  # The input value to be processed by the flow
    "output_type": "chat",  # Specifies the expected output format
    "input_type": "chat"  # Specifies the input format
}

# Request headers
headers = {
    "Content-Type": "application/json"
}

try:
    # Send API request
    response = requests.request("POST", url, json=payload, headers=headers)
    response.raise_for_status()  # Raise exception for bad status codes

    # Print response
    print(response.text)

except requests.exceptions.RequestException as e:
    print(f"Error making API request: {e}")
except ValueError as e:
    print(f"Error parsing response: {e}")
# Out:
# {"session_id":"bab7bc55-6ffb-48a9-af06-c9a65cd11e60","outputs":[{"inputs":{"input_value":"hello world!"},"outputs":[{"results":{"message":{"text_key":"text","data":{"timestamp":"2025-04-17T10:00:57+00:00","sender":"Machine","sender_name":"AI","session_id":"bab7bc55-6ffb-48a9-af06-c9a65cd11e60","text":"Hello World! 很高兴见到你！如果你有任何编程或技术相关的问题，随时可以问我哦！😊","files":[],"error":false,"edit":false,"properties":{"text_color":"","background_color":"","edited":false,"source":{"id":"OpenRouterComponent-bgkrV","display_name":"OpenRouter","source":"qwen/qwen-max"},"icon":"OpenRouter","allow_markdown":false,"positive_feedback":null,"state":"complete","targets":[]},"category":"message","content_blocks":[],"id":"d42b6aa9-7f38-4df0-a70c-ec3a73cb7323","flow_id":"bab7bc55-6ffb-48a9-af06-c9a65cd11e60"},"default_value":"","text":"Hello World! 很高兴见到你！如果你有任何编程或技术相关的问题，随时可以问我哦！😊","sender":"Machine","sender_name":"AI","files":[],"session_id":"bab7bc55-6ffb-48a9-af06-c9a65cd11e60","timestamp":"2025-04-17T10:00:57+00:00","flow_id":"bab7bc55-6ffb-48a9-af06-c9a65cd11e60","error":false,"edit":false,"properties":{"text_color":"","background_color":"","edited":false,"source":{"id":"OpenRouterComponent-bgkrV","display_name":"OpenRouter","source":"qwen/qwen-max"},"icon":"OpenRouter","allow_markdown":false,"positive_feedback":null,"state":"complete","targets":[]},"category":"message","content_blocks":[]}},"artifacts":{"message":"Hello World! 很高兴见到你！如果你有任何编程或技术相关的问题，随时可以问我哦！😊","sender":"Machine","sender_name":"AI","files":[],"type":"object"},"outputs":{"message":{"message":"Hello World! 很高兴见到你！如果你有任何编程或技术相关的问题，随时可以问我哦！😊","type":"text"}},"logs":{"message":[]},"messages":[{"message":"Hello World! 很高兴见到你！如果你有任何编程或技术相关的问题，随时可以问我哦！😊","sender":"Machine","sender_name":"AI","session_id":"bab7bc55-6ffb-48a9-af06-c9a65cd11e60","stream_url":null,"component_id":"ChatOutput-P9ija","files":[],"type":"text"}],"timedelta":null,"duration":null,"component_display_name":"Chat Output","component_id":"ChatOutput-P9ija","used_frozen_result":false}]}]}

# %% [markdown]
# ---

# %% [markdown]
# ## stream 格式

# %%
import requests
url = "http://127.0.0.1:7860/api/v1/run/bab7bc55-6ffb-48a9-af06-c9a65cd11e60?stream=true"  # The complete API endpoint URL for this flow

# Request payload configuration
payload = {
    "input_value": "距离地球最近的行星是那颗",  # The input value to be processed by the flow
    "output_type": "chat",  # Specifies the expected output format
    "input_type": "chat"  # Specifies the input format
}

# Request headers
headers = {
    "Content-Type": "application/json"
}

try:
    # Send API request
    with requests.request("POST", url, json=payload, headers=headers, stream=True) as response:
        if response.status_code == 200:
            for chunk in response.iter_content():
                print(chunk.decode('utf-8'), end="")
    # import json
    # with requests.request("POST", url, json=payload, headers=headers, stream=True) as response:
    #     if response.status_code == 200:
    #         for chunk in response.iter_lines():
    #             res = chunk.decode('utf-8')
    #             if res:
    #                 res_j = json.loads(res)
    #                 if res_j.get('data') and res_j.get('data').get('chunk'):
    #                     print(res_j.get('data').get('chunk'), end="")

except requests.exceptions.RequestException as e:
    print(f"Error making API request: {e}")
except ValueError as e:
    print(f"Error parsing response: {e}")
# Out:
# {"event": "add_message", "data": {"timestamp": "2025-04-17T10:09:51", "sender": "User", "sender_name": "User", "session_id": "bab7bc55-6ffb-48a9-af06-c9a65cd11e60", "text": "\u8ddd\u79bb\u5730\u7403\u6700\u8fd1\u7684\u884c\u661f\u662f\u90a3\u9897", "files": [], "error": false, "edit": false, "properties": {"text_color": "", "background_color": "", "edited": false, "source": {"id": null, "display_name": null, "source": null}, "icon": "", "allow_markdown": false, "positive_feedback": null, "state": "complete", "targets": []}, "category": "message", "content_blocks": [], "id": "77244d85-91f5-4c15-b4e5-9a9b3820a940", "flow_id": "bab7bc55-6ffb-48a9-af06-c9a65cd11e60"}}
#
# {"event": "add_message", "data": {"timestamp": "2025-04-17T10:09:51", "sender": "Machine", "sender_name": "AI", "session_id": "bab7bc55-6ffb-48a9-af06-c9a65cd11e60", "text": "", "files": [], "error": false, "edit": false, "properties": {"text_color": "", "background_color": "", "edited": false, "source": {"id": "OpenRouterComponent-bgkrV", "display_name": "OpenRouter", "source": "qwen/qwen-max"}, "icon": "OpenRouter", "allow_markdown": false, "positive_feedback": null, "state": "complete", "targets": []}, "category": "message", "content_blocks": [], "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "flow_id": "bab7bc55-6ffb-48a9-af06-c9a65cd11e60"}}
#
# {"event": "token", "data": {"chunk": "", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:53 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u8ddd\u79bb\u5730\u7403\u6700\u8fd1", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:53 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u7684\u884c\u661f\u662f**", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:53 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u91d1\u661f**\u3002\n\n", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:53 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u4e0d\u8fc7\uff0c\u8fd9\u4e2a\u95ee\u9898\u7684\u7b54\u6848\u53ef\u80fd\u4f1a", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:54 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u56e0\u65f6\u95f4\u800c\u53d8\u5316\uff0c", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:54 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u56e0\u4e3a\u884c\u661f\u7684\u76f8\u5bf9", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:54 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u4f4d\u7f6e\u5728\u4e0d\u65ad\u53d8\u5316\u3002", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:54 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u4ece\u5e73\u5747\u8ddd\u79bb\u6765\u770b\uff0c\u91d1", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:54 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u661f\u662f\u79bb\u5730\u7403\u6700\u8fd1\u7684", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:54 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u884c\u661f\u3002\u7136\u800c\uff0c\u5728", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:54 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u67d0\u4e9b\u60c5\u51b5\u4e0b\uff0c**", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:54 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u6c34\u661f**\u4e5f\u53ef\u80fd", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:55 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u6bd4\u91d1\u661f\u66f4", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:55 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u63a5\u8fd1\u5730\u7403\uff0c\u56e0\u4e3a", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:55 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u6c34\u661f\u7684\u8f68\u9053", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:55 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u66f4\u9760\u8fd1\u592a\u9633\uff0c", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:55 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u4e14\u5b83\u7684\u8f68\u9053\u534a", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:55 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u5f84\u8f83\u5c0f\u3002\n\n\u6709\u8da3", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:55 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u7684\u662f\uff0c\u5982\u679c\u4ece\u201c", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:55 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u5e73\u5747\u6700\u8fd1\u8ddd\u79bb\u201d\u7684", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:55 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u89d2\u5ea6\u6765\u770b\uff0c**\u6c34", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:56 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u661f**\u5b9e\u9645\u4e0a\u662f\u592a\u9633", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:56 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u7cfb\u4e2d\u4e0e\u5730\u7403\u5e73\u5747", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:56 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u8ddd\u79bb\u6700\u8fd1\u7684\u884c\u661f", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:56 UTC"}}
#
# {"event": "token", "data": {"chunk": "\uff01\u8fd9\u662f\u56e0\u4e3a\u6c34\u661f\u7684", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:56 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u8f68\u9053\u9760\u8fd1\u592a\u9633\uff0c\u5b83", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:56 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u5728\u5730\u7403\u8f68\u9053\u5185", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:56 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u7684\u65f6\u95f4\u66f4\u591a\uff0c\u5bfc\u81f4", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:56 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u4ece\u7edf\u8ba1\u5b66\u4e0a\u770b\uff0c", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:57 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u6c34\u661f\u4e0e\u5730\u7403\u7684\u5e73\u5747", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:57 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u8ddd\u79bb\u66f4\u77ed\u3002\n\n", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:57 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u603b\u7ed3\uff1a\n- **", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:57 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u91d1\u661f**\uff1a\u901a\u5e38", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:57 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u88ab\u8ba4\u4e3a\u662f\u79bb\u5730\u7403\u6700\u8fd1\u7684\u884c\u661f", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:57 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u3002\n- **\u6c34\u661f**", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:57 UTC"}}
#
# {"event": "token", "data": {"chunk": "\uff1a\u4ece\u5e73\u5747\u8ddd\u79bb\u6765\u770b\uff0c", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:58 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u4e5f\u662f\u5730\u7403\u6700\u8fd1\u7684\u90bb\u5c45", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:58 UTC"}}
#
# {"event": "token", "data": {"chunk": "\u4e4b\u4e00\u3002", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:58 UTC"}}
#
# {"event": "token", "data": {"chunk": "", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:58 UTC"}}
#
# {"event": "token", "data": {"chunk": "", "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "timestamp": "2025-04-17 10:09:58 UTC"}}
#
# {"event": "end", "data": {"result": {"session_id": "bab7bc55-6ffb-48a9-af06-c9a65cd11e60", "outputs": [{"inputs": {"input_value": "\u8ddd\u79bb\u5730\u7403\u6700\u8fd1\u7684\u884c\u661f\u662f\u90a3\u9897"}, "outputs": [{"results": {"message": {"text_key": "text", "data": {"timestamp": "2025-04-17T10:09:51+00:00", "sender": "Machine", "sender_name": "AI", "session_id": "bab7bc55-6ffb-48a9-af06-c9a65cd11e60", "text": "", "files": [], "error": false, "edit": false, "properties": {"text_color": "", "background_color": "", "edited": false, "source": {"id": "OpenRouterComponent-bgkrV", "display_name": "OpenRouter", "source": "qwen/qwen-max"}, "icon": "OpenRouter", "allow_markdown": false, "positive_feedback": null, "state": "complete", "targets": []}, "category": "message", "content_blocks": [], "id": "7adf2bdc-94e6-4e65-8d3d-2fb2be01a12e", "flow_id": "bab7bc55-6ffb-48a9-af06-c9a65cd11e60"}, "default_value": "", "text": "", "sender": "Machine", "sender_name": "AI", "files": [], "session_id": "bab7bc55-6ffb-48a9-af06-c9a65cd11e60", "timestamp": "2025-04-17T10:09:51+00:00", "flow_id": "bab7bc55-6ffb-48a9-af06-c9a65cd11e60", "error": false, "edit": false, "properties": {"text_color": "", "background_color": "", "edited": false, "source": {"id": "OpenRouterComponent-bgkrV", "display_name": "OpenRouter", "source": "qwen/qwen-max"}, "icon": "OpenRouter", "allow_markdown": false, "positive_feedback": null, "state": "complete", "targets": []}, "category": "message", "content_blocks": []}, "text": ""}, "artifacts": {"message": "", "sender": "Machine", "sender_name": "AI", "stream_url": "/api/v1/build/bab7bc55-6ffb-48a9-af06-c9a65cd11e60/ChatOutput-P9ija/stream", "files": [], "type": "stream"}, "outputs": {"message": {"message": "\u8ddd\u79bb\u5730\u7403\u6700\u8fd1\u7684\u884c\u661f\u662f**\u91d1\u661f**\u3002\n\n\u4e0d\u8fc7\uff0c\u8fd9\u4e2a\u95ee\u9898\u7684\u7b54\u6848\u53ef\u80fd\u4f1a\u56e0\u65f6\u95f4\u800c\u53d8\u5316\uff0c\u56e0\u4e3a\u884c\u661f\u7684\u76f8\u5bf9\u4f4d\u7f6e\u5728\u4e0d\u65ad\u53d8\u5316\u3002\u4ece\u5e73\u5747\u8ddd\u79bb\u6765\u770b\uff0c\u91d1\u661f\u662f\u79bb\u5730\u7403\u6700\u8fd1\u7684\u884c\u661f\u3002\u7136\u800c\uff0c\u5728\u67d0\u4e9b\u60c5\u51b5\u4e0b\uff0c**\u6c34\u661f**\u4e5f\u53ef\u80fd\u6bd4\u91d1\u661f\u66f4\u63a5\u8fd1\u5730\u7403\uff0c\u56e0\u4e3a\u6c34\u661f\u7684\u8f68\u9053\u66f4\u9760\u8fd1\u592a\u9633\uff0c\u4e14\u5b83\u7684\u8f68\u9053\u534a\u5f84\u8f83\u5c0f\u3002\n\n\u6709\u8da3\u7684\u662f\uff0c\u5982\u679c\u4ece\u201c\u5e73\u5747\u6700\u8fd1\u8ddd\u79bb\u201d\u7684\u89d2\u5ea6\u6765\u770b\uff0c**\u6c34\u661f**\u5b9e\u9645\u4e0a\u662f\u592a\u9633\u7cfb\u4e2d\u4e0e\u5730\u7403\u5e73\u5747\u8ddd\u79bb\u6700\u8fd1\u7684\u884c\u661f\uff01\u8fd9\u662f\u56e0\u4e3a\u6c34\u661f\u7684\u8f68\u9053\u9760\u8fd1\u592a\u9633\uff0c\u5b83\u5728\u5730\u7403\u8f68\u9053\u5185\u7684\u65f6\u95f4\u66f4\u591a\uff0c\u5bfc\u81f4\u4ece\u7edf\u8ba1\u5b66\u4e0a\u770b\uff0c\u6c34\u661f\u4e0e\u5730\u7403\u7684\u5e73\u5747\u8ddd\u79bb\u66f4\u77ed\u3002\n\n\u603b\u7ed3\uff1a\n- **\u91d1\u661f**\uff1a\u901a\u5e38\u88ab\u8ba4\u4e3a\u662f\u79bb\u5730\u7403\u6700\u8fd1\u7684\u884c\u661f\u3002\n- **\u6c34\u661f**\uff1a\u4ece\u5e73\u5747\u8ddd\u79bb\u6765\u770b\uff0c\u4e5f\u662f\u5730\u7403\u6700\u8fd1\u7684\u90bb\u5c45\u4e4b\u4e00\u3002", "type": "text"}}, "logs": {"message": []}, "messages": [], "timedelta": null, "duration": null, "component_display_name": "Chat Output", "component_id": "ChatOutput-P9ija", "used_frozen_result": false}]}]}}}

# %% [markdown]
# ---

# %% [markdown]
# ## Context 上下文 (Session 会话)

# %%
import requests
url = "http://127.0.0.1:7860/api/v1/run/f575fd1b-b849-45e4-b4f0-879fb7c558e7"  # The complete API endpoint URL for this flow

# Request payload configuration
payload = {
    "input_value": "金星呢?",  # The input value to be processed by the flow
    "output_type": "chat",  # Specifies the expected output format
    "input_type": "chat",  # Specifies the input format
    "session_id": "102"  # Optional session ID for tracking
}

# Request headers
headers = {
    "Content-Type": "application/json"
}

try:
    # Send API request
    response = requests.request("POST", url, json=payload, headers=headers)
    response.raise_for_status()  # Raise exception for bad status codes

    # Print response
    print(response.text)

    import json
    print(json.dumps(json.loads(response.text), indent=4, ensure_ascii=False))

except requests.exceptions.RequestException as e:
    print(f"Error making API request: {e}")
except ValueError as e:
    print(f"Error parsing response: {e}")
# Out:
# {"session_id":"102","outputs":[{"inputs":{"input_value":"金星呢?"},"outputs":[{"results":{"message":{"text_key":"text","data":{"timestamp":"2025-04-17T15:40:43+00:00","sender":"Machine","sender_name":"AI","session_id":"102","text":"金星与地球的距离同样会因为两颗行星的轨道位置而不断变化。金星是地球的“内邻”，其轨道位于地球轨道的内侧，因此它与地球的距离变化范围比火星要小。\n\n### 1. **金星与地球最近距离**\n当地球和金星在它们的轨道上分别位于太阳的同一侧，并且金星与地球处于最近的位置时，这种状态被称为“**下合**”。在下合时，金星与地球的最近距离大约为**3800万公里**（约**2360万英里**）。这是金星与地球之间可能达到的最近距离。\n\n### 2. **金星与地球最远距离**\n当地球和金星分别位于太阳的两侧时，它们之间的距离最远，可能达到约**2.61亿公里**（约**1.62亿英里**）。\n\n### 3. **金星的轨道特性**\n金星的轨道比地球更接近太阳，且轨道较为接近圆形。因此，金星与地球的距离变化主要取决于两颗行星的相对位置。金星的“下合”周期大约是**584天**，即每隔约1年半，金星和地球会接近一次。\n\n总结来说，金星与地球的最近距离大约为**3800万公里**，而最远距离则约为**2.61亿公里**。","files":[],"error":false,"edit":false,"properties":{"text_color":"","background_color":"","edited":false,"source":{"id":"OpenRouterComponent-bgkrV","display_name":"OpenRouter","source":"qwen/qwen-max"},"icon":"OpenRouter","allow_markdown":false,"positive_feedback":null,"state":"complete","targets":[]},"category":"message","content_blocks":[],"id":"f48fc4a9-6338-43e5-9532-f5842b9ff971","flow_id":"f575fd1b-b849-45e4-b4f0-879fb7c558e7"},"default_value":"","text":"金星与地球的距离同样会因为两颗行星的轨道位置而不断变化。金星是地球的“内邻”，其轨道位于地球轨道的内侧，因此它与地球的距离变化范围比火星要小。\n\n### 1. **金星与地球最近距离**\n当地球和金星在它们的轨道上分别位于太阳的同一侧，并且金星与地球处于最近的位置时，这种状态被称为“**下合**”。在下合时，金星与地球的最近距离大约为**3800万公里**（约**2360万英里**）。这是金星与地球之间可能达到的最近距离。\n\n### 2. **金星与地球最远距离**\n当地球和金星分别位于太阳的两侧时，它们之间的距离最远，可能达到约**2.61亿公里**（约**1.62亿英里**）。\n\n### 3. **金星的轨道特性**\n金星的轨道比地球更接近太阳，且轨道较为接近圆形。因此，金星与地球的距离变化主要取决于两颗行星的相对位置。金星的“下合”周期大约是**584天**，即每隔约1年半，金星和地球会接近一次。\n\n总结来说，金星与地球的最近距离大约为**3800万公里**，而最远距离则约为**2.61亿公里**。","sender":"Machine","sender_name":"AI","files":[],"session_id":"102","timestamp":"2025-04-17T15:40:43+00:00","flow_id":"f575fd1b-b849-45e4-b4f0-879fb7c558e7","error":false,"edit":false,"properties":{"text_color":"","background_color":"","edited":false,"source":{"id":"OpenRouterComponent-bgkrV","display_name":"OpenRouter","source":"qwen/qwen-max"},"icon":"OpenRouter","allow_markdown":false,"positive_feedback":null,"state":"complete","targets":[]},"category":"message","content_blocks":[]}},"artifacts":{"message":"金星与地球的距离同样会因为两颗行星的轨道位置而不断变化。金星是地球的“内邻”，其轨道位于地球轨道的内侧，因此它与地球的距离变化范围比火星要小。\n\n### 1. **金星与地球最近距离**\n\n当地球和金星在它们的轨道上分别位于太阳的同一侧，并且金星与地球处于最近的位置时，这种状态被称为“**下合**”。在下合时，金星与地球的最近距离大约为**3800万公里**（约**2360万英里**）。这是金星与地球之间可能达到的最近距离。\n\n### 2. **金星与地球最远距离**\n\n当地球和金星分别位于太阳的两侧时，它们之间的距离最远，可能达到约**2.61亿公里**（约**1.62亿英里**）。\n\n### 3. **金星的轨道特性**\n\n金星的轨道比地球更接近太阳，且轨道较为接近圆形。因此，金星与地球的距离变化主要取决于两颗行星的相对位置。金星的“下合”周期大约是**584天**，即每隔约1年半，金星和地球会接近一次。\n\n总结来说，金星与地球的最近距离大约为**3800万公里**，而最远距离则约为**2.61亿公里**。","sender":"Machine","sender_name":"AI","files":[],"type":"object"},"outputs":{"message":{"message":"金星与地球的距离同样会因为两颗行星的轨道位置而不断变化。金星是地球的“内邻”，其轨道位于地球轨道的内侧，因此它与地球的距离变化范围比火星要小。\n\n### 1. **金星与地球最近距离**\n当地球和金星在它们的轨道上分别位于太阳的同一侧，并且金星与地球处于最近的位置时，这种状态被称为“**下合**”。在下合时，金星与地球的最近距离大约为**3800万公里**（约**2360万英里**）。这是金星与地球之间可能达到的最近距离。\n\n### 2. **金星与地球最远距离**\n当地球和金星分别位于太阳的两侧时，它们之间的距离最远，可能达到约**2.61亿公里**（约**1.62亿英里**）。\n\n### 3. **金星的轨道特性**\n金星的轨道比地球更接近太阳，且轨道较为接近圆形。因此，金星与地球的距离变化主要取决于两颗行星的相对位置。金星的“下合”周期大约是**584天**，即每隔约1年半，金星和地球会接近一次。\n\n总结来说，金星与地球的最近距离大约为**3800万公里**，而最远距离则约为**2.61亿公里**。","type":"text"}},"logs":{"message":[]},"messages":[{"message":"金星与地球的距离同样会因为两颗行星的轨道位置而不断变化。金星是地球的“内邻”，其轨道位于地球轨道的内侧，因此它与地球的距离变化范围比火星要小。\n\n### 1. **金星与地球最近距离**\n\n当地球和金星在它们的轨道上分别位于太阳的同一侧，并且金星与地球处于最近的位置时，这种状态被称为“**下合**”。在下合时，金星与地球的最近距离大约为**3800万公里**（约**2360万英里**）。这是金星与地球之间可能达到的最近距离。\n\n### 2. **金星与地球最远距离**\n\n当地球和金星分别位于太阳的两侧时，它们之间的距离最远，可能达到约**2.61亿公里**（约**1.62亿英里**）。\n\n### 3. **金星的轨道特性**\n\n金星的轨道比地球更接近太阳，且轨道较为接近圆形。因此，金星与地球的距离变化主要取决于两颗行星的相对位置。金星的“下合”周期大约是**584天**，即每隔约1年半，金星和地球会接近一次。\n\n总结来说，金星与地球的最近距离大约为**3800万公里**，而最远距离则约为**2.61亿公里**。","sender":"Machine","sender_name":"AI","session_id":"102","stream_url":null,"component_id":"ChatOutput-P9ija","files":[],"type":"text"}],"timedelta":null,"duration":null,"component_display_name":"Chat Output","component_id":"ChatOutput-P9ija","used_frozen_re ...
# {
#     "session_id": "102",
#     "outputs": [
#         {
#             "inputs": {
#                 "input_value": "金星呢?"
#             },
#             "outputs": [
#                 {
#                     "results": {
#                         "message": {
#                             "text_key": "text",
#                             "data": {
#                                 "timestamp": "2025-04-17T15:40:43+00:00",
#                                 "sender": "Machine",
#                                 "sender_name": "AI",
#                                 "session_id": "102",
#                                 "text": "金星与地球的距离同样会因为两颗行星的轨道位置而不断变化。金星是地球的“内邻”，其轨道位于地球轨道的内侧，因此它与地球的距离变化范围比火星要小。\n\n### 1. **金星与地球最近距离**\n当地球和金星在它们的轨道上分别位于太阳的同一侧，并且金星与地球处于最近的位置时，这种状态被称为“**下合**”。在下合时，金星与地球的最近距离大约为**3800万公里**（约**2360万英里**）。这是金星与地球之间可能达到的最近距离。\n\n### 2. **金星与地球最远距离**\n当地球和金星分别位于太阳的两侧时，它们之间的距离最远，可能达到约**2.61亿公里**（约**1.62亿英里**）。\n\n### 3. **金星的轨道特性**\n金星的轨道比地球更接近太阳，且轨道较为接近圆形。因此，金星与地球的距离变化主要取决于两颗行星的相对位置。金星的“下合”周期大约是**584天**，即每隔约1年半，金星和地球会接近一次。\n\n总结来说，金星与地球的最近距离大约为**3800万公里**，而最远距离则约为**2.61亿公里**。",
#                                 "files": [],
#                                 "error": false,
#                                 "edit": false,
#                                 "properties": {
#                                     "text_color": "",
#                                     "background_color": "",
#                                     "edited": false,
#                                     "source": {
#                                         "id": "OpenRouterComponent-bgkrV",
#                                         "display_name": "OpenRouter",
#                                         "source": "qwen/qwen-max"
#                                     },
#                                     "icon": "OpenRouter",
#                                     "allow_markdown": false,
#                                     "positive_feedback": null,
#                                     "state": "complete",
#                                     "targets": []
#                                 },
#                                 "category": "message",
#                                 "content_blocks": [],
#                                 "id": "f48fc4a9-6338-43e5-9532-f5842b9ff971",
#                                 "flow_id": "f575fd1b-b849-45e4-b4f0-879fb7c558e7"
#                             },
#                             "default_value": "",
#                             "text": "金星与地球的距离同样会因为两颗行星的轨道位置而不断变化。金星是地球的“内邻”，其轨道位于地球轨道的内侧，因此它与地球的距离变化范围比火星要小。\n\n### 1. **金星与地球最近距离**\n当地球和金星在它们的轨道上分别位于太阳的同一侧，并且金星与地球处于最近的位置时，这种状态被称为“**下合**”。在下合时，金星与地球的最近距离大约为**3800万公里**（约**2360万英里**）。这是金星与地球之间可能达到的最近距离。\n\n### 2. **金星与地球最远距离**\n当地球和金星分别位于太阳的两侧时，它们之间的距离最远，可能达到约**2.61亿公里**（约**1.62亿英里**）。\n\n### 3. **金星的轨道特性**\n金星的轨道比地球更接近太阳，且轨道较为接近圆形。因此，金星与地球的距离变化主要取决于两颗行星的相对位置。金星的“下合”周期大约是**584天**，即每隔约1年半，金星和地球会接近一次。\n\n总结来说，金星与地球的最近距离大约为**3800万公里**，而最远距离则约为**2.61亿公里**。",
#                             "sender": "Machine",
#                             "sender_name": "AI",
#                             "files": [],
#                             "session_id": "102",
#                             "timestamp": "2025-04-17T15:40:43+00:00",
#                             "flow_id": "f575fd1b-b849-45e4-b4f0-879fb7c558e7",
#                             "error": false,
#                             "edit": false,
#                             "properties": {
#                                 "text_color": "",
#                                 "background_color": "",
#                                 "edited": false,
#                                 "source": {
#                                     "id": "OpenRouterComponent-bgkrV",
#                                     "display_name": "OpenRouter",
#                                     "source": "qwen/qwen-max"
#                                 },
#                                 "icon": "OpenRouter",
#                                 "allow_markdown": false,
#                                 "positive_feedback": null,
#                                 "state": "complete",
#                                 "targets": []
#                             },
#                             "category": "message",
#                             "content_blocks": []
#                         }
#                     },
#                     "artifacts": {
#                         "message": "金星与地球的距离同样会因为两颗行星的轨道位置而不断变化。金星是地球的“内邻”，其轨道位于地球轨道的内侧，因此它与地球的距离变化范围比火星要小。\n\n### 1. **金星与地球最近距离**\n\n当地球和金星在它们的轨道上分别位于太阳的同一侧，并且金星与地球处于最近的位置时，这种状态被称为“**下合**”。在下合时，金星与地球的最近距离大约为**3800万公里**（约**2360万英里**）。这是金星与地球之间可能达到的最近距离。\n\n### 2. **金星与地球最远距离**\n\n当地球和金星分别位于太阳的两侧时，它们之间的距离最远，可能达到约**2.61亿公里**（约**1.62亿英里**）。\n\n### 3. **金星的轨道特性**\n\n金星的轨道比地球更接近太阳，且轨道较为接近圆形。因此，金星与地球的距离变化主要取决于两颗行星的相对位置。金星的“下合”周期大约是**584天**，即每隔约1年半，金星和地球会接近一次。\n\n总结来说，金星与地球的最近距离大约为**3800万公里**，而最远距离则约为**2.61亿公里**。",
#                         "sender": "Machine",
#                         "sender_name": "AI",
#                         "files": [],
#                         "type": "object"
#                     },
#                     "outputs": {
#                         "message": {
#                             "message": "金星与地球的距离同样会因为两颗行星的轨道位置而不断变化。金星是地球的“内邻”，其轨道位于地球轨道的内侧，因此它与地球的距离变化范围比火星要小。\n\n### 1. **金星与地球最近距离**\n当地球和金星在它们的轨道上分别位于太阳的同一侧，并且金星与地球处于最近的位置时，这种状态被称为“**下合**”。在下合时，金星与地球的最近距离大约为**3800万公里**（约**2360万英里**）。这是金星与地球之间可能达到的最近距离。\n\n### 2. **金星与地球最远距离**\n当地球和金星分别位于太阳的两侧时，它们之间的距离最远，可能达到约**2.61亿公里**（约**1.62亿英里**）。\n\n### 3. **金星的轨道特性**\n金星的轨道比地球更接近太阳，且轨道较为接近圆形。因此，金星与地球的距离变化主要取决于两颗行星的相对位置。金星的“下合”周期大约是**584天**，即每隔约1年半，金星和地球会接近一次。\n\n总结来说，金星与地球的最近距离大约为**3800万公里**，而最远距离则约为**2.61亿公里**。",
#                             "type": "text"
#                         }
#                     },
#                     "logs": {
#                         "message": []
#                     },
#                     "messages": [
#                         {
#                             "message": "金星与地球的距离同样会因为两颗行星的轨道位置而不断变化。金星是地球的“内邻”，其轨道位于地球轨道的内侧，因此它与地球的距离变化范围比火星要小。\n\n### 1. **金星与地球最近距离**\n\n当地球和金星在它们的轨道上分别位于太阳的同一侧，并且金星与地球处于最近的位置时，这种状态被称为“**下合**”。在下合时，金星与地球的最近距离大约为**3800万公里**（约**2360万英里**）。这是金星与地球之间可能达到的最近距离。\n\n### 2. **金星与地球最远距离**\n\n当地球和金星分别位于太阳的两侧时，它们之间的距离最远，可能达到约**2.61亿公里**（约**1.62亿英里**）。\n\n### 3. **金星的轨道特性**\n\n金星的轨道比地球更接近太阳，且轨道较为接近圆形。因此，金星与地球的距离变化主要取决于两颗行星的相对位置。金星的“下合”周期大约是**584天**，即每隔约1年半，金星和地球会接近一次。\n\n总结来说，金星与地球的最近距离大约为**3800万公里**，而最远距离则约为**2.61亿公里**。",
#                             "sender": "Machine",
#                             "sender_name": "AI",
#                             "session_id": "102",
#                             "stream_url": null,
#                             "component_id": "ChatOutput-P9ija",
#                             "files": [],
#                             "type": "text"
#                         }
#                     ],
#                     "timedelta": null,
#                     "duration": null,
#                     "component_display_name": "Chat Output",
#                     "component_id": "ChatOutput-P9ija",
#                     "used_frozen_result": false
#                 }
#             ]
#         }
#     ]
# }
